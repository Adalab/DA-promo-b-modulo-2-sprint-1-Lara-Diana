# %%
# En este ejercicio pondremos en práctica los conceptos básicos para juntar varios csv que compartan información.
# Trabajaremos con tres ficheros diferentes:
# El csv que creamos en el ejercicio de pair programming Pandas IV, dónde recordamos eliminamos ciertas columnas que no eran necesarias, y habíamos creado nuevas.
# El csv llamado attacks_historico donde tenemos información sobre los ataques de tiburón previos al año 1800.
# El csv llamado attacks_adicional donde tenemos información sobre los ataques de tiburón.

# %%
import pandas as pd

# %%
# Para llevar a cabo nuestro objetivo tendréis que seguir los siguientes pasos:
# 1-Cargad los tres ficheros nombrados anteriormente y los exploramos para familizarizarnos con ellos 
# y saber que información tienen en común y debatir con tu compañera como podríamos juntar toda la información.

df1=pd.read_csv('./datos/attacks_IV')
df1.head()
# Out:
#    Unnamed: 0   case-number  unnamed:-0    year        type    country  \
# 0           0    2018.06.25           0  2018.0     Boating        USA
# 1           6  2018.06.03.a           6  2018.0  Unprovoked     BRAZIL
# 2           8  2018.05.26.b           8  2018.0  Unprovoked        USA
# 3          10    2018.05.24          10  2018.0    Provoked  AUSTRALIA
# 4          13  2018.05.13.a          13  2018.0     Invalid    ENGLAND
#
#          area                      location        activity  \
# 0  California   Oceanside, San Diego County        Paddling
# 1  Pernambuco         Piedade Beach, Recife        Swimming
# 2     Florida  Cocoa Beach, Brevard  County         Walking
# 3  Queensland               Cairns Aquarium  Feeding sharks
# 4    Cornwall                Off Land's End         Fishing
#
#                      name sex- age            time          species-  \
# 0             Julie Wolfe    F  57           18h00       White shark
# ...

# %%
df2=pd.read_csv('./datos/attacks_adicional.csv')
df2.head()
# Out:
#    Unnamed: 0 Case Number Fatal (Y/N)  \
# 0           0  2018.06.25           N
# 1           1  2018.06.18           N
# 2           2  2018.06.09           N
# 3           3  2018.06.08           N
# 4           4  2018.06.04           N
#
#                                               Injury         Date
# 0  No injury to occupant, outrigger canoe and pad...  25-Jun-2018
# 1                         Minor injury to left thigh  18-Jun-2018
# 2       Injury to left lower leg from surfboard skeg  09-Jun-2018
# 3                          Minor injury to lower leg  08-Jun-2018
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT  04-Jun-2018

# %%
df3=pd.read_csv('./datos/attacks_historico.csv')
df3.head()
# Out:
#    Unnamed: 0   Case Number    Year        Type     Country             Area  \
# 0        6132    1800.00.00  1800.0  Unprovoked  SEYCHELLES         St. Anne
# 1        6133  1797.05.28.R  1797.0  Unprovoked         NaN              NaN
# 2        6134    1792.09.12  1792.0    Provoked     ENGLAND              NaN
# 3        6135    1791.00.00  1791.0  Unprovoked   AUSTRALIA  New South Wales
# 4        6136    1788.05.10  1788.0        Boat   AUSTRALIA  New South Wales
#
#               Location                         Activity  \
# 0                  NaN  a corsair's boat was overturned
# 1                  NaN                Dropped overboard
# 2  On the Thames River                          Fishing
# 3         Port Jackson                              NaN
# 4        Sydney Harbor                          Fishing
#
#                                Name Sex   ... Species   \
# 0                               NaN    F  ...      NaN
# ...

# %%
# 2-Chequead que los nombres de las columnas que sean iguales entre dataframes son iguales. ¿Están todas en minúsculas? 
# ¿Tienen espacios? En caso de que no sean todas iguales unificad el nombre de las columnas.

print(df1.columns)
print(df2.columns)
print(df3.columns)
# Out:
# Index(['Unnamed: 0', 'case-number', 'unnamed:-0', 'year', 'type', 'country',
#        'area', 'location', 'activity', 'name', 'sex-', 'age', 'time',
#        'species-', 'href', 'siglo'],
#       dtype='object')
# Index(['Unnamed: 0', 'Case Number', 'Fatal (Y/N)', 'Injury', 'Date'], dtype='object')
# Index(['Unnamed: 0', 'Case Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
# 3-En este momento nos habremos dado cuenta que el DataFrame que generamos en el pair programming Pandas IV 
# es similar al DataFrame de los datos historicos. Si recordamos, eliminamos algunas columnas en la sesión III que 
# no eran útiles, pero esas columnas están todavía en el histórico. Si no fuera por eso podríamos unir esos dataframes.
# Realizad los cambios que creais necesarios para que los dataframes sean iguales y luego juntadlos usando el mejor método.

#PRIMERO MODIFICAMOS EL PROBLEMA DE LAS MAYÚSCULAS
columnas_nuevas = {col : col.capitalize() for col in df1.columns} 
df1.rename(columns = columnas_nuevas, inplace=True)
columnas_nuevas2 = {col:col.replace('-',' ') for col in df1.columns}
df1.rename(columns = columnas_nuevas2, inplace=True)
df1
# Out:
#       Unnamed: 0   Case number  Unnamed: 0    Year        Type       Country  \
# 0              0    2018.06.25           0  2018.0     Boating           USA
# 1              6  2018.06.03.a           6  2018.0  Unprovoked        BRAZIL
# 2              8  2018.05.26.b           8  2018.0  Unprovoked           USA
# 3             10    2018.05.24          10  2018.0    Provoked     AUSTRALIA
# 4             13  2018.05.13.a          13  2018.0     Invalid       ENGLAND
# ...          ...           ...         ...     ...         ...           ...
# 1497        5528    1901.07.30        5545  1901.0  Unprovoked  SOUTH AFRICA
# 1498        5631    1894.11.28        5648  1894.0  Unprovoked     AUSTRALIA
# 1499        5667    1892.03.02        5684  1892.0    Provoked     AUSTRALIA
# 1500        5797    1880.11.25        5814  1880.0  Unprovoked     AUSTRALIA
# 1501        5905    1868.05.13        5922  1868.0  Unprovoked         INDIA
#
# ...

# %%
# Eliminad las columnas que no coincidan para poder ejecutar el merge
df3.drop(['Unnamed: 22','Unnamed: 23','Case Number.1','Case Number.2','original order','Investigator or Source','pdf','href formula'],axis=1,inplace=True)
df3.head()
# Out:
#    Unnamed: 0   Case Number    Year        Type     Country             Area  \
# 0        6132    1800.00.00  1800.0  Unprovoked  SEYCHELLES         St. Anne
# 1        6133  1797.05.28.R  1797.0  Unprovoked         NaN              NaN
# 2        6134    1792.09.12  1792.0    Provoked     ENGLAND              NaN
# 3        6135    1791.00.00  1791.0  Unprovoked   AUSTRALIA  New South Wales
# 4        6136    1788.05.10  1788.0        Boat   AUSTRALIA  New South Wales
#
#               Location                         Activity  \
# 0                  NaN  a corsair's boat was overturned
# 1                  NaN                Dropped overboard
# 2  On the Thames River                          Fishing
# 3         Port Jackson                              NaN
# 4        Sydney Harbor                          Fishing
#
#                                Name Sex   Age Time Species   \
# 0                               NaN    F  NaN  NaN      NaN
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Case number', 'Unnamed: 0', 'Year', 'Type', 'Country',
#        'Area', 'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time',
#        'Species ', 'Href', 'Siglo'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['Unnamed: 0', 'Case Number', 'Year', 'Type', 'Country', 'Area',
#        'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time', 'Species ',
#        'href'],
#       dtype='object')

# %%
df1.rename(columns={'Case number':'Case Number'},inplace=True)
df1.columns
# Out:
# Index(['Unnamed: 0', 'Case Number', 'Unnamed: 0', 'Year', 'Type', 'Country',
#        'Area', 'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time',
#        'Species ', 'Href', 'Siglo'],
#       dtype='object')

# %%
df1.rename(columns={'Species ':'Species'},inplace=True)
df1.columns
# Out:
# Index(['Unnamed: 0', 'Case Number', 'Unnamed: 0', 'Year', 'Type', 'Country',
#        'Area', 'Location', 'Activity', 'Name', 'Sex ', 'Age', 'Time',
#        'Species', 'Href', 'Siglo'],
#       dtype='object')

# %%
df1.rename(columns={'Sex ':'Sex'},inplace=True)
df1.columns
# Out:
# Index(['Unnamed: 0', 'Case Number', 'Unnamed: 0', 'Year', 'Type', 'Country',
#        'Area', 'Location', 'Activity', 'Name', 'Sex', 'Age', 'Time', 'Species',
#        'Href', 'Siglo'],
#       dtype='object')

# %%
df1.drop(['Unnamed: 0'],axis=1,inplace=True)
df1.columns
# Out:
# Index(['Case Number', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex', 'Age', 'Time', 'Species', 'Href', 'Siglo'],
#       dtype='object')

# %%
df_concat = pd.concat([df1, df3], axis=0, ignore_index = True)
df_concat.head()
# Out:
#     Case Number    Year        Type    Country        Area  \
# 0    2018.06.25  2018.0     Boating        USA  California
# 1  2018.06.03.a  2018.0  Unprovoked     BRAZIL  Pernambuco
# 2  2018.05.26.b  2018.0  Unprovoked        USA     Florida
# 3    2018.05.24  2018.0    Provoked  AUSTRALIA  Queensland
# 4  2018.05.13.a  2018.0     Invalid    ENGLAND    Cornwall
#
#                        Location        Activity                    Name Sex  \
# 0   Oceanside, San Diego County        Paddling             Julie Wolfe   F
# 1         Piedade Beach, Recife        Swimming  Jose Ernesto da Silva    M
# 2  Cocoa Beach, Brevard  County         Walking               Cody High   M
# 3               Cairns Aquarium  Feeding sharks                    male   M
# 4                Off Land's End         Fishing            Max Berryman   M
#
#   Age            Time           Species  \
# 0  57           18h00       White shark
# 1  18  Late afternoon       Tiger shark
# ...

# %%
df_final5 = pd.merge(left=df_concat, right=df2, how='left', on = 'Case Number')

df_final5.head()
# Out:
#     Case Number    Year        Type    Country        Area  \
# 0    2018.06.25  2018.0     Boating        USA  California
# 1  2018.06.03.a  2018.0  Unprovoked     BRAZIL  Pernambuco
# 2  2018.05.26.b  2018.0  Unprovoked        USA     Florida
# 3    2018.05.24  2018.0    Provoked  AUSTRALIA  Queensland
# 4  2018.05.13.a  2018.0     Invalid    ENGLAND    Cornwall
#
#                        Location        Activity                    Name Sex  \
# 0   Oceanside, San Diego County        Paddling             Julie Wolfe   F
# 1         Piedade Beach, Recife        Swimming  Jose Ernesto da Silva    M
# 2  Cocoa Beach, Brevard  County         Walking               Cody High   M
# 3               Cairns Aquarium  Feeding sharks                    male   M
# 4                Off Land's End         Fishing            Max Berryman   M
#
#   Age  ...                                               Href        Siglo  \
# ...

# %%
# 3-En este momento nos habremos dado cuenta que el DataFrame que generamos en el pair programming Pandas IV
# es similar al DataFrame de los datos historicos. Si recordamos, eliminamos algunas columnas en la sesión III 
# que no eran útiles, pero esas columnas están todavía en el histórico.

#  Si no fuera por eso podríamos unir esos dataframes. Realizad los cambios que creais necesarios para que los dataframes sean iguales y luego juntadlos usando el mejor método.
# 4-Es el momento de unir la información de todos los ataques de tiburón que acabamos de crear con el DataFrame de información adicional. Debatid que método es el más correcto para unir toda esta información y ejecutadlo.
# 5-Guardad el dataframe nuevo en un csv que usaremos mañana en la clase de pair programming

# %%
df_final5.shape
# Out:
# (1672, 22)

# %%
attack_merge = df_final5.to_csv('attacks_pandas5.csv', index = False)
